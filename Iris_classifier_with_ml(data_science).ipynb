# %% [markdown]
# <a href="https://colab.research.google.com/github/berak636/Oasisinfobyte/blob/main/Iris_classifier_with_ml(data_science).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# uploading the data set in code
columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class_species']
datas = pd.read_csv("iris data.csv", names= columns)
datas.head()
# Out:
#    sepal length  sepal width  petal length  petal width class_species
# 0           5.1          3.5           1.4          0.2   Iris-setosa
# 1           4.9          3.0           1.4          0.2   Iris-setosa
# 2           4.7          3.2           1.3          0.2   Iris-setosa
# 3           4.6          3.1           1.5          0.2   Iris-setosa
# 4           5.0          3.6           1.4          0.2   Iris-setosa

# %%
# visualizing the data to check the no of rows and colomn
datas.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# visualization the  whole dataset with help of the lib seaborn
# before importing create a coloumnn
sns.pairplot(df, hue='class_species')

# %% [markdown]
# Seprating the input coloumns and op coloumns

# %%
# seprating feture and label
data = datas.values
x = data[:,0:4]
y = data[:,4]

# %% [markdown]
# spliting the data into traing and testing

# %%
#spliting the testing and traning dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %% [markdown]
#  diff machine learning algo for prediction

# %%
from sklearn.svm import SVC
model_svc=SVC()
model_svc.fit(x_train, y_train)
# Out:
# SVC()

# %% [markdown]
# Calculating the accuracy

# %%
prediction1 = model_svc.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction1)*100)
# Out:
# 100.0

# %% [markdown]
# Model 2: Logistic regression

# %%
from sklearn.linear_model import LogisticRegression
model_lr=LogisticRegression()
model_lr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Calculating accuracy of Logistic Regression

# %%
prediction2 = model_lr.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction2)*100)
# Out:
# 100.0

# %% [markdown]
# Model 3: Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
model_dtc=DecisionTreeClassifier()
model_dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# claculating accuracy of Decision Tree Classifier

# %%
prediction3 = model_dtc.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, prediction3)*100)
# Out:
# 100.0

# %% [markdown]
# A detail classification report but there were 3 option decision tree and logistic regression I choose decision tree

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction3))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       1.00      1.00      1.00         6
#  Iris-virginica       1.00      1.00      1.00        10
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30

# %%
x_new = np.array([[3,4,1,1], [32,45,56,1], [4.9,2.2,3.8,1.1]])
# prediction of the species based on the input given above
prediction = model_dtc.predict(x_new)
print("prediction of the species:{} ".format(prediction))
# Out:
# prediction of the species:['Iris-versicolor' 'Iris-virginica' 'Iris-versicolor']
